# %% [markdown]
# <p style='font-size:150%'><i><u>Overview</u></i></p>
#
# <p>In this practical we were required to write python code to fulfill the following requirements:
# <p>    1. Check the consistency of the initial (raw) data.
# <p>    2. In case of any inconsistencies, output refined data for further analysis.
# <p>    3. Provide an executable Python script to automate the two steps above.
# <p>    4. Implement unit tests to check at least some of the auxiliary functions.
# <p>    5. Carry out certain data analysis and visualisation tasks.
# <p>    6. Provide an executable Python script to regenerate all images and save them in a directory.
# <p>    7. Provide a reproducible Jupyter notebook combining your report and data analysis.
# <p>    8. Organise code with minimal duplication for its reuse in Jupyter notebook(s) and Python scripts.

# %%
import pandas as pd
import csv

# %%
df=pd.read_csv("../data/CometLandingRefined.csv")

# %%
df
# Out:
#              id_str        from_user  \
# 0      5.409304e+17  amika0078788556
# 1      5.409300e+17   ChrisDMarshall
# 2      5.409300e+17         MHuuskoL
# 3      5.409293e+17  SaraGomezAranci
# 4      5.409292e+17          CBCDay6
# ...             ...              ...
# 77047  5.324601e+17     ABForScience
# 77048  5.324601e+17           atieyK
# 77049  5.324601e+17           j0nny5
# 77050  5.324601e+17          nsentse
# 77051  5.324601e+17          grery92
#
#                                                     text              time  \
# 0      RT @VersaTechnology: Congratulations @Philae20...  05/12/2014 18:07
# 1      CometWatch 2 December Â» Rosetta - ESA's comet...  05/12/2014 18:05
# 2      RT @EUCouncil: After the #CometLanding - Astro...  05/12/2014 18:05
# 3      RT @EUCouncil: After the #CometLanding - Astro...  05/12/2014 18:03
# 4      RT @shaunmajumder: Feels good to be the @CBCDa...  05/12/2014 18:02
# ...                                                  ...               ...
# 77047  This means  that the actual landing will be ar...  12/11/2014 09:09
# 77048  RT @ObservingSpace: Weâ€™ve been waiting 10 ye...  12/11/2014 09:09
# 77049  RT @maxplanckpress: Accomazzo (flight director...  12/11/2014 09:09
# 77050                   7 hours of waiting #CometLanding  12/11/2014 09:09
# 77051  RT @dsdanyds: TopTrendIT: TT ITALIA 09:59\n1.#...  12/11/2014 09:09
#
#       user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0            en                      NaN                     NaN
# 1            en                      NaN                     NaN
# 2            en                      NaN                     NaN
# 3            fr                      NaN                     NaN
# 4            en                      NaN                     NaN
# ...         ...                      ...                     ...
# 77047        en                      NaN                     NaN
# 77048        en                      NaN                     NaN
# 77049        en                      NaN                     NaN
# 77050        en                      NaN                     NaN
# 77051        it                      NaN                     NaN
#
#        from_user_id_str  in_reply_to_status_id_str  \
# 0          1.297570e+09                        NaN
# 1          4.220121e+07                        NaN
# 2          5.744348e+08                        NaN
# 3          1.057356e+09                        NaN
# 4          1.772769e+08                        NaN
# ...                 ...                        ...
# 77047      2.333123e+09                        NaN
# 77048      5.830372e+07                        NaN
# 77049      1.791486e+07                        NaN
# 77050      2.043400e+07                        NaN
# 77051      4.878276e+08                        NaN
#
#                                                   source  \
# 0      <a href="http://twitter.com" rel="nofollow">Tw...
# 1      <a href="https://dev.twitter.com/docs/tfw" rel...
# 2      <a href="http://twitter.com/#!/download/ipad" ...
# 3      <a href="http://twitter.com/download/iphone" r...
# 4      <a href="http://twitter.com/download/android" ...
# ...                                                  ...
# 77047  <a href="http://www.tweetcaster.com" rel="nofo...
# 77048  <a href="https://twitter.com/download/android"...
# 77049  <a href="http://twitter.com" rel="nofollow">Tw...
# 77050  <a href="http://twitter.com/download/iphone" r...
# 77051  <a href="http://twitter.com/download/android" ...
#
#                                        profile_image_url  \
# 0      http://pbs.twimg.com/profile_images/3555068293...
# 1      http://pbs.twimg.com/profile_images/228087980/...
# 2      http://pbs.twimg.com/profile_images/4973510588...
# 3      http://pbs.twimg.com/profile_images/5391705804...
# 4      http://pbs.twimg.com/profile_images/4590694303...
# ...                                                  ...
# 77047  http://pbs.twimg.com/profile_images/4320695593...
# 77048  http://pbs.twimg.com/profile_images/5057311637...
# 77049  http://pbs.twimg.com/profile_images/89991673/j...
# 77050  http://pbs.twimg.com/profile_images/3693655850...
# 77051  http://pbs.twimg.com/profile_images/3788000004...
#
#        user_followers_count  user_friends_count  \
# 0                     425.0               113.0
# 1                     347.0              1286.0
# 2                     215.0               310.0
# 3                     741.0               310.0
# 4                    4331.0              2098.0
# ...                     ...                 ...
# 77047                 155.0               212.0
# 77048                 354.0              1088.0
# 77049                  92.0                63.0
# 77050                 200.0               267.0
# 77051                 194.0               403.0
#
#                                               status_url  \
# 0      http://twitter.com/amika0078788556/statuses/54...
# 1      http://twitter.com/ChrisDMarshall/statuses/540...
# 2      http://twitter.com/MHuuskoL/statuses/540929998...
# 3      http://twitter.com/SaraGomezAranci/statuses/54...
# 4      http://twitter.com/CBCDay6/statuses/5409292290...
# ...                                                  ...
# 77047  http://twitter.com/ABForScience/statuses/53246...
# 77048  http://twitter.com/atieyK/statuses/53246014845...
# 77049  http://twitter.com/j0nny5/statuses/53246014825...
# 77050  http://twitter.com/nsentse/statuses/5324601482...
# 77051  http://twitter.com/grery92/statuses/5324601477...
#
#                                             entities_str
# 0      {"hashtags":[{"text":"Philae","indices":[49,56...
# 1      {"hashtags":[{"text":"CometLanding","indices":...
# 2      {"hashtags":[{"text":"CometLanding","indices":...
# 3      {"hashtags":[{"text":"CometLanding","indices":...
# 4      {"hashtags":[{"text":"MiniMansbridge","indices...
# ...                                                  ...
# 77047  {"hashtags":[{"text":"CometLanding","indices":...
# 77048  {"hashtags":[{"text":"cometlanding","indices":...
# 77049  {"hashtags":[{"text":"CometLanding","indices":...
# 77050  {"hashtags":[{"text":"CometLanding","indices":...
# 77051  {"hashtags":[{"text":"GUERRIERO","indices":[44...
#
# [77052 rows x 15 columns]

# %%
len(df)
# Out:
# 77052

# %%
df.dtypes
# Out:
# id_str                       float64
# from_user                     object
# text                          object
# time                          object
# user_lang                     object
# in_reply_to_user_id_str      float64
# in_reply_to_screen_name       object
# from_user_id_str             float64
# in_reply_to_status_id_str    float64
# source                        object
# profile_image_url             object
# user_followers_count         float64
# user_friends_count           float64
# status_url                    object
# entities_str                  object
# dtype: object

# %%
df.sort_values(by='time', ascending=True)
# Out:
#             id_str        from_user  \
# 1629  5.392087e+17     jorgerojas00
# 1628  5.392089e+17     jorgerojas00
# 1627  5.392089e+17            x5_dc
# 1626  5.392089e+17            x5_dc
# 1625  5.392091e+17            x5_dc
# ...            ...              ...
# 1654  5.391976e+17  haileysecretary
# 1642  5.391976e+17        gg_rainey
# 1648  5.391976e+17       philominax
# 1631  5.392013e+17           diuk37
# 1630  5.392047e+17    ben_economics
#
#                                                    text              time  \
# 1629  RT @UniversoCnocido: En una sola imagen todos ...  01/12/2014 00:05
# 1628  RT @UniversoCnocido: .@Philae2014 ya estÃ¡ seg...  01/12/2014 00:06
# 1627  RT @ScienceNews: Good night, Philae. We may se...  01/12/2014 00:06
# 1626  RT @SNStudents: This photo shows the primary l...  01/12/2014 00:06
# 1625  RT @ScienceNews: Philae lander sent in a surpr...  01/12/2014 00:07
# ...                                                 ...               ...
# 1654  RT @heyyouapp: â™¦ http://t.co/2XlG5hzBTP 584 ...  30/11/2014 23:21
# 1642  RT @heyyouapp: â™¦ http://t.co/2XlG5hzBTP 584 ...  30/11/2014 23:21
# 1648  RT @heyyouapp: â™¦ http://t.co/2XlG5hzBTP 584 ...  30/11/2014 23:21
# 1631  RT @davidshukmanbbc: Interesting new take on #...  30/11/2014 23:36
# 1630  RT @rjmlaird: My @ESA_Rosetta t-shirts have ar...  30/11/2014 23:49
#
#      user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 1629        es                      NaN                     NaN
# 1628        es                      NaN                     NaN
# 1627        en                      NaN                     NaN
# 1626        en                      NaN                     NaN
# 1625        en                      NaN                     NaN
# ...        ...                      ...                     ...
# 1654        en                      NaN                     NaN
# 1642        en                      NaN                     NaN
# 1648        en                      NaN                     NaN
# 1631        en                      NaN                     NaN
# 1630        fr                      NaN                     NaN
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 1629      2.225624e+08                        NaN
# 1628      2.225624e+08                        NaN
# 1627      2.177027e+09                        NaN
# 1626      2.177027e+09                        NaN
# 1625      2.177027e+09                        NaN
# ...                ...                        ...
# 1654      2.533836e+09                        NaN
# 1642      2.298687e+09                        NaN
# 1648      2.593948e+09                        NaN
# 1631      1.483404e+08                        NaN
# 1630      3.442382e+08                        NaN
#
#                                                  source  \
# 1629  <a href="http://twitter.com/download/android" ...
# 1628  <a href="http://twitter.com/download/android" ...
# 1627  <a href="http://blackberry.com/twitter" rel="n...
# 1626  <a href="http://blackberry.com/twitter" rel="n...
# 1625  <a href="http://blackberry.com/twitter" rel="n...
# ...                                                 ...
# 1654  <a href="http://dlvr.it" rel="nofollow">dlvr.i...
# 1642  <a href="http://dlvr.it" rel="nofollow">dlvr.i...
# 1648  <a href="http://dlvr.it" rel="nofollow">dlvr.i...
# 1631  <a href="http://twitter.com/download/iphone" r...
# 1630  <a href="http://www.twitter.com" rel="nofollow...
#
#                                       profile_image_url  user_followers_count  \
# 1629  http://pbs.twimg.com/profile_images/3788000003...                 212.0
# 1628  http://pbs.twimg.com/profile_images/3788000003...                 212.0
# 1627  http://pbs.twimg.com/profile_images/4720773348...                 146.0
# 1626  http://pbs.twimg.com/profile_images/4720773348...                 146.0
# 1625  http://pbs.twimg.com/profile_images/4720773348...                 146.0
# ...                                                 ...                   ...
# 1654  http://pbs.twimg.com/profile_images/4721885586...                4678.0
# 1642  http://pbs.twimg.com/profile_images/4246920285...                3651.0
# 1648  http://pbs.twimg.com/profile_images/4830475987...                3208.0
# 1631  http://pbs.twimg.com/profile_images/4532615914...                 224.0
# 1630  http://pbs.twimg.com/profile_images/5115941099...                 288.0
#
#       user_friends_count                                         status_url  \
# 1629               372.0  http://twitter.com/jorgerojas00/statuses/53920...
# 1628               372.0  http://twitter.com/jorgerojas00/statuses/53920...
# 1627               906.0  http://twitter.com/x5_dc/statuses/539208924105...
# 1626               906.0  http://twitter.com/x5_dc/statuses/539208940975...
# 1625               906.0  http://twitter.com/x5_dc/statuses/539209059581...
# ...                  ...                                                ...
# 1654              4896.0  http://twitter.com/haileysecretary/statuses/53...
# 1642              3820.0  http://twitter.com/gg_rainey/statuses/53919759...
# 1648              3523.0  http://twitter.com/philominax/statuses/5391975...
# 1631               544.0  http://twitter.com/diuk37/statuses/53920131224...
# 1630               444.0  http://twitter.com/ben_economics/statuses/5392...
#
#                                            entities_str
# 1629  {"hashtags":[{"text":"CometLanding","indices":...
# 1628  {"hashtags":[{"text":"CometLanding","indices":...
# 1627  {"hashtags":[{"text":"cometlanding","indices":...
# 1626  {"hashtags":[{"text":"67P","indices":[99,103]}...
# 1625  {"hashtags":[{"text":"cometlanding","indices":...
# ...                                                 ...
# 1654  {"hashtags":[{"text":"cometlanding","indices":...
# 1642  {"hashtags":[{"text":"cometlanding","indices":...
# 1648  {"hashtags":[{"text":"cometlanding","indices":...
# 1631  {"hashtags":[{"text":"CometLanding","indices":...
# 1630  {"hashtags":[{"text":"CometLanding","indices":...
#
# [77052 rows x 15 columns]

# %%
df['time']=pd.to_datetime(df['time'], dayfirst=True)

# %%
day=df.groupby(df['time'].dt.date)

# %%
day.size()
# Out:
# time
# 2014-11-12    73094
# 2014-11-26      396
# 2014-11-27      485
# 2014-11-28      700
# 2014-11-29      416
# 2014-11-30      331
# 2014-12-01      591
# 2014-12-02      463
# 2014-12-03      303
# 2014-12-04      195
# 2014-12-05       78
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Graphs to show tweet activity over time.
#
# First, a bar chart:

# %%
df['time'].dt.date.value_counts().plot(kind="bar").set(xlabel='Dates of Tweets', ylabel='Tweets count', title='Tweets Count Against Date')
plt.show()

# %% [markdown]
# Let's get a better look with a log scale:

# %%
df['time'].dt.date.value_counts().plot(kind="bar").set(yscale='log', xlabel='Dates of Tweets', ylabel='Tweets count', title='Tweets Count with Log Scale Against Date')
plt.show()

# %% [markdown]
# Now a line graph:

# %%
df.sort_values(by='time', ascending=True)
df['time']=pd.to_datetime(df['time'], dayfirst=True)

df['time'].dt.date.value_counts().plot(figsize=(25,15))
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# Once again, let's get a better look by using a log scale on the y-axis

# %%
df['time'].dt.date.value_counts().plot(figsize=(25,15), logy=True)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# Check number of different (unique) users

# %%
# https://stackoverflow.com/questions/36106490/how-to-get-unique-values-from-multiple-columns-in-a-pandas-groupby
# By Yaakov Bressler (Last accessed date: 08-04-2022)
users=df.groupby(df['from_user_id_str']).agg(['unique'])
unique_users = len(users.index)

# %% [markdown]
# Number of replies

# %%
df_replies=df[['in_reply_to_user_id_str', 'in_reply_to_screen_name']]
df_replies=df_replies.dropna(subset=['in_reply_to_user_id_str', 'in_reply_to_screen_name'], how='all')

# %%
len(df_replies.index)
# Out:
# 1718

# %% [markdown]
# Lets have a look at what languages the tweets are in:

# %%
#Only display languages that appear frequently, lets say more than 400 times.
df2 = df.groupby('user_lang').filter(lambda x : len(x)<400)
lst = df2['user_lang'].tolist()
lst = list(dict.fromkeys(lst))
lst
for ln in lst:
    df['user_lang'].replace(ln, 'other', inplace=True)

# %%
lang=df.groupby(df['user_lang'])

# %%
lang.size()
# Out:
# user_lang
# ar         401
# de        2914
# en       54166
# es        7534
# fr        3309
# it        2655
# ja        1508
# nl         838
# other     1669
# pt         508
# ru         791
# tr         759
# dtype: int64

# %%
csfont = {'fontname':'Serif'}
df['user_lang'].value_counts().plot(kind="pie", figsize=(21,21), fontsize=20, autopct='%1.1f%%', pctdistance=1.25)
plt.xlabel("")
plt.ylabel("")
plt.title(label="User Languages", fontsize=50, fontstyle="italic", **csfont, fontweight="bold")
plt.legend(loc='upper left',fontsize=21)
plt.show()

# %% [markdown]
# We can also determine the frequency of hashtags

# %%
import json
import re
df = pd.read_csv("../data/CometLandingRefined.csv")['entities_str']
df.reset_index()
# Out:
#        index                                       entities_str
# 0          0  {"hashtags":[{"text":"Philae","indices":[49,56...
# 1          1  {"hashtags":[{"text":"CometLanding","indices":...
# 2          2  {"hashtags":[{"text":"CometLanding","indices":...
# 3          3  {"hashtags":[{"text":"CometLanding","indices":...
# 4          4  {"hashtags":[{"text":"MiniMansbridge","indices...
# ...      ...                                                ...
# 77047  77047  {"hashtags":[{"text":"CometLanding","indices":...
# 77048  77048  {"hashtags":[{"text":"cometlanding","indices":...
# 77049  77049  {"hashtags":[{"text":"CometLanding","indices":...
# 77050  77050  {"hashtags":[{"text":"CometLanding","indices":...
# 77051  77051  {"hashtags":[{"text":"GUERRIERO","indices":[44...
#
# [77052 rows x 2 columns]

# %%
lst = []
for index in range(df.shape[0]):
    results = re.findall(r"{\"text\":\".+\",", str(df.iloc[index]))
    for i in results:
        if(i.startswith('{\"text\":\"') and i.endswith("\",")):
            ents=i.split(",")
            ents=filter(lambda x: "text" in str(x), ents)
            for j in ents:
                lst.append(j)

# %%
cleanlst = []
lst=filter(lambda x: "{\"text\":" in str(x), lst)
for i in lst:
    lst2 = i.split(":")
    cleanlst.append(lst2[1].replace("\"", ""))
print('Total number of hashtags: ' + str(len(cleanlst)))
# Out:
# Total number of hashtags: 115113

# %% [markdown]
# iterate down the rows
# take final column
# code that extract and take top 10

# %%
from collections import Counter
from itertools import chain
hashtag_counts=Counter(cleanlst)
plt.figure(figsize=(20,10))
hashtag_plot=plt.bar(*zip(*hashtag_counts.most_common()[:10]), width=0.4) # Getting the top 10 most frequent hashtags
plt.xticks(fontsize=9.5)
plt.xlabel("Hashtags", fontsize=12, fontweight="bold")
plt.ylabel("Frequency", fontsize=12, fontweight="bold")
plt.title("Frequency Against Hashtags", fontsize=16, fontweight="bold")
plt.show()

# %% [markdown]
# Just for fun - lets create a wordcloud for hashtag content

# %%
from wordcloud import WordCloud
# removing duplicates from cleanlst
unique_cleanlst = list(dict.fromkeys(cleanlst))
text_for_word_cloud = ' '.join(unique_cleanlst)
word_cloud = WordCloud(collocations=False, background_color='white').generate(text_for_word_cloud)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df = pd.read_csv("../data/CometLandingRefined.csv")
size_all = len(df)
#Remove all retweets
def retweet(inp):
    if(str(inp).startswith("RT @")):
        return True
    else:
        return False
df=df[df['text'].map(retweet) == False]
num_retweets = size_all - len(df)

# %%
num_retweets
# Out:
# 59857

# %%
df_replies=df[['in_reply_to_user_id_str', 'in_reply_to_screen_name']]
df_replies=df_replies.dropna(subset=['in_reply_to_user_id_str', 'in_reply_to_screen_name'], how='all')
replies = len(df_replies.index)

# %%
standard_tweets = len(df) - replies
standard_tweets
# Out:
# 15507

# %%
data = {'Tweets':standard_tweets, 'Retweets':num_retweets, 'Replies':replies}
types = list(data.keys())
values = list(data.values())
plt.figure(figsize=(20,10))
plt.bar(types, values, width=0.4)
plt.xticks(fontsize=15, fontstyle='italic')
plt.yticks(fontsize=15, fontstyle='italic')
plt.xlabel('Type of tweet', fontsize=17, fontweight='bold')
plt.ylabel('Occurrences', fontsize=17, fontweight='bold')
plt.title('Occurrences of types of tweets', fontsize=17, fontweight='bold')
plt.show()

# %%
print("Average number of tweets per user: " + str(standard_tweets/unique_users))
print("Average number of retweets per user: " + str(num_retweets/unique_users))
print("Average number of replies per user: " + str(replies/unique_users))
# Out:
# Average number of tweets per user: 0.3093233862602729
# Average number of retweets per user: 1.1939878720178727
# Average number of replies per user: 0.03367110827415623
